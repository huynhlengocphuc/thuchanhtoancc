# %% [markdown]
# <a href="https://colab.research.google.com/github/huynhlengocphuc/thuchanhtoancc/blob/main/ch%C6%B0%C6%A1ng_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
mienchia=np.linspace(0,2,11)
mienchia
# Out:
# array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ])

# %%
fig,ax=plt.subplots()
for f in fs:
  y=np.sin(2*np.pi*f*t)
  ax.plot(t,y,label='{}Hz'.format(f))

# %%
for f in fs:
  y=np.sin(2*np.pi*f*t)
  plt.plot(t,y,label='{}Hz'.format(f))

# %%
def f (x):return x**2

# %%
print(f(8))
# Out:
# 64

# %%
g=lambda x: x**2

# %%
print(g(8))
# Out:
# 64

# %%
def thue(phan_tram):return lambda x:x*phan_tram
hcm=thue(0.12)
hn=thue(0.01)
hcm(1000000)
# Out:
# 120000.0

# %%
hn(1000000)
# Out:
# 10000.0

# %%
hinhthang=lambda f,a,b:(b-a)*(f(a)+f(b))/2
from math import exp
hinhthang(exp,0,1)
# Out:
# 1.8591409142295225

# %%
import scipy
from sympy import*
import sys
sys.displayhook=pprint
x=Symbol('x')
bt1=integrate(x**2+x+1,x)
pprint(bt1)
bt2=integrate(x/(x**2+2*x+1),x)
pprint(bt2)
bt3=integrate(x**2*exp(x)*cos(x),x)
pprint(bt3)
bt4=integrate(exp(-x**2)*erf(x),x)
pprint(bt4)
# Out:
#  3    2
# x    x
# ── + ── + x
# 3    2
#                1
# log(x + 1) + ─────
#              x + 1
#  2  x           2  x                         x           x
# x ⋅ℯ ⋅sin(x)   x ⋅ℯ ⋅cos(x)      x          ℯ ⋅sin(x)   ℯ ⋅cos(x)
# ──────────── + ──────────── - x⋅ℯ ⋅sin(x) + ───────── - ─────────
#      2              2                           2           2
#       2
# √π⋅erf (x)
# ──────────
#     4
# None

# %%
from sympy import Integral,Symbol
x=Symbol('x')
k=Symbol('k')
Integral(k*x,x)
# Out:
# Integral(k*x, x)

# %%
Integral(k*x,x).doit()
# Out:
# k*x**2/2

# %%
from sympy import pprint,Integral
F=Integral(k*x,x).doit()
pprint(F)
# Out:
#    2
# k⋅x
# ────
#  2

# %%
Integral(k*x,(x,0,2)).doit()
# Out:
# 2*k

# %%
from sympy import Integral,Symbol
x=Symbol('x')
Integral(x,(x,2,4)).doit()
# Out:
# 6

# %%
from sympy import Symbol,exp,sqrt,pi,Integral
x=Symbol('x')
p=exp(-(x-10)**2/2)/sqrt(2*pi)
Integral(p,(x,11,12)).doit().evalf()
# Out:
# 0.135905121983278

# %%
def hai_x(x):
  return 2*x

# %%
hinhthang(hai_x,1,2)
# Out:
# 3.0

# %%
def traprule(ham,trai,phai):
  return(phai_trai)*(ham(trai)+ham(phai))/2

# %%
import math
S="Bieu thuc can tinh tich phan la e^x:"
print(S+'[a,b]')
A=float(input('Nhap a:'))
B=float(input('Nhap b:'))
Y=traprule(math.exp,A,B)
print(S+"[%.1E,%.1E]:"%(A,B))
print('Gia tri xap xi:%.15E'%Y)
E=math.exp(B)-math.exp(A)
print('Gia tri chinh xac:%.15E'%E)
# Out:
# Bieu thuc can tinh tich phan la e^x:[a,b]
